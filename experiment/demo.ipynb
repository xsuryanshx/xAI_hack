# %%
import os
import socket
import time

# Fix for gRPC DNS resolution issue: Force gRPC to use system DNS resolver instead of c-ares
# This must be set BEFORE importing grpc or xai_sdk
os.environ['GRPC_DNS_RESOLVER'] = 'native'  # Use system DNS resolver instead of c-ares

from xai_sdk import Client
from xai_sdk.chat import user
from xai_sdk.tools import web_search, x_search, code_execution
import dotenv
dotenv.load_dotenv()

# Check API key
api_key = os.getenv("XAI_API_KEY")
if not api_key:
    raise ValueError("XAI_API_KEY environment variable is not set. Please set it before running this code.")

# Check network connectivity
def check_dns_resolution(hostname):
    """Check if DNS resolution works for a hostname"""
    try:
        socket.gethostbyname(hostname)
        return True
    except socket.gaierror:
        return False

print("Checking network connectivity...")
if not check_dns_resolution("api.x.ai"):
    print("Warning: DNS resolution for api.x.ai failed. This might be a network issue.")
    print("Please check:")
    print("1. Your internet connection")
    print("2. DNS server settings")
    print("3. Firewall/proxy settings")
    print("4. VPN connection (if using)")
    print("\nAttempting to continue anyway...")

# Create client with error handling
try:
    client = Client(api_key=api_key)
    print("Client created successfully.")
except Exception as e:
    print(f"Error creating client: {e}")
    raise

# Create chat with retry logic
max_retries = 3
retry_delay = 2

for attempt in range(max_retries):
    try:
        chat = client.chat.create(
            model="grok-4-1-fast",  # reasoning model
            # All server-side tools active
            tools=[
                web_search(),
                x_search(),
                code_execution(),
            ],
        )
        print("Chat session created successfully.")
        break
    except Exception as e:
        if attempt < max_retries - 1:
            print(f"Attempt {attempt + 1} failed: {e}")
            print(f"Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay)
        else:
            print(f"Failed after {max_retries} attempts: {e}")
            raise

# Feel free to change the query here to a question of your liking
chat.append(user("What are the latest updates from xAI?"))

is_thinking = True
response = None

try:
    for response, chunk in chat.stream():
        # View the server-side tool calls as they are being made in real-time
        for tool_call in chunk.tool_calls:
            print(f"\nCalling tool: {tool_call.function.name} with arguments: {tool_call.function.arguments}")
        if response.usage.reasoning_tokens and is_thinking:
            print(f"\rThinking... ({response.usage.reasoning_tokens} tokens)", end="", flush=True)
        if chunk.content and is_thinking:
            print("\n\nFinal Response:")
            is_thinking = False
        if chunk.content and not is_thinking:
            print(chunk.content, end="", flush=True)
except Exception as e:
    print(f"\n\nError during streaming: {e}")
    print("\nThis might be due to:")
    print("1. Network connectivity issues")
    print("2. DNS resolution problems")
    print("3. API endpoint unavailability")
    print("4. Invalid API key")
    raise

if response:
    print("\n\nCitations:")
    print(response.citations)
    print("\n\nUsage:")
    print(response.usage)
    print(response.server_side_tool_usage)
    print("\n\nServer Side Tool Calls:")
    print(response.tool_calls)
# Out:
# Checking network connectivity...
# Client created successfully.
# Chat session created successfully.
#
# Calling tool: x_user_search with arguments: {"query":"xAI","count":5}
# Thinking... (478 tokens)
# Calling tool: x_keyword_search with arguments: {"query":"from:xai","limit":20,"mode":"Latest"}
# Thinking... (478 tokens)
# Calling tool: x_keyword_search with arguments: {"query":"from:xai OR from:elonmusk xai","limit":20,"mode":"Latest"}
# Thinking... (478 tokens)
# Calling tool: x_semantic_search with arguments: {"query":"latest updates from xAI","limit":20,"usernames":["xai"]}
# Thinking... (478 tokens)
# Calling tool: browse_page with arguments: {"url": "https://x.ai/"}
# Thinking... (478 tokens)
# Calling tool: browse_page with arguments: {"url": "https://x.ai/blog"}
# Thinking... (478 tokens)
# Calling tool: web_search with arguments: {"query":"xAI latest updates news","num_results":15}
# Thinking... (1036 tokens)
#
# Final Response:
# **Latest Updates from xAI (as of December 6, 2025)**
#
# xAI's most recent announcements come from their official X account (@xai) and website (x.ai). Here's a summary of the top updates from November 2025, in reverse chronological order:
#
# ### November 19, 2025: Grok 4.1 Fast and xAI Agent Tools API
# - **Key Highlights**:
#   - Launched **Grok 4.1 Fast**, a new tool-calling model with a 2M-token context window, optimized for enterprise use cases like customer support and deep research.
#   - Tops agentic search benchmarks with native X integration, code execution, web browsing, and real-time info retrieval.
#   - **Agent Tools API** now available: Developers can enable autonomous web browsing, X searches, code execution, document retrieval, etc., with just a few lines of code.
#   - Free for 2 weeks (Grok 4.1 Fast also free on OpenRouter). Paid API pricing: $0.2/1M input tokens, $0.5/1M output.
# - **Availability**: xAI API (docs.x.ai).
# - **Links**: [Announcement Thread](https://x.com/xai/status/1991284813727474073), [Blog](https://x.ai/news/grok-4-1-fast).
#
# ### November 19, 2025: Partnership with Saudi Arabia (KSA) and HUMAIN
# - **Key Highlights**:
#   - Landmark deal: xAI to build hyperscale GPU data centers in Saudi Arabia and deploy Grok nationwide—the first country-scale adoption.
#   - Supports Saudi's "Most AI-Enabled Nation" goals.
# - **Links**: [xAI Blog](https://x.ai/news/grok-goes-global/), [HUMAIN Press Release](https://www.humain.com/en/news/humain-and-xai-partner-to-build-next-generation-ai-compute-power-and-deploy-grok-in-the-kingdom-to-support-the-most-ai-enabled-nation-objectives).
#
# ### November 17, 2025: Grok 4.1 Release
# - **Key Highlights**:
#   - Frontier model excelling in conversational intelligence, emotional understanding (1586 EQ-Bench), creative writing (1722 Elo on Creative Writing v3, +600 points), and real-world helpfulness.
#   - #1 on LMSYS Arena leaderboard (1483 Elo, 31 points ahead of competitors).
#   - 3x fewer hallucinations; user preference 65% over prior models (silent rollout tested earlier).
#   - Available to **all users** (free tier included) on grok.com, X, iOS/Android apps.
# - **Links**: [Announcement Thread](https://x.com/xai/status/1990530499752980638), [Blog](https://x.ai/news/grok-4-1/).
#
# ### Other Recent Mentions
# - **November 10, 2025**: xAI Hackathon announced (24-hour event with exclusive Grok/X API access; apply by Nov 22). [Details](https://x.ai/hackathon).
# - **Elon Musk Updates** (related):
#   - Grokipedia (to be renamed Encyclopedia Galactica): Massive open-source knowledge repo for the universe, with redundancy across solar system. Hiring engineers.
.com/i/status/1990530510582657533', 'https://x.com/i/user/1661523610111193088', 'https://x.com/i/user/1875560944044273665', 'https://x.com/i/status/1841625252977340476', 'https://x.com/i/status/1990530499752980638', 'https://x.com/i/status/1991284828667527322', 'https://x.com/i/status/1987696575314104339', 'https://x.com/i/status/1990660994570277014', 'https://techcrunch.com/tag/xai/', 'https://x.com/i/user/1019237602585645057', 'https://x.com/i/status/1950828488405254268', 'https://x.com/xai', 'https://www.benzinga.com/topic/xai', 'https://x.com/i/status/1981917247095685441', 'https://x.com/i/status/1991224224313487696', 'https://x.com/i/status/1990530508770718154']
#
#
# Usage:
# completion_tokens: 1140
# prompt_tokens: 25993
# total_tokens: 28169
# prompt_text_tokens: 25993
# reasoning_tokens: 1036
# cached_prompt_text_tokens: 2665
# server_side_tools_used: SERVER_SIDE_TOOL_X_SEARCH
# server_side_tools_used: SERVER_SIDE_TOOL_X_SEARCH
# server_side_tools_used: SERVER_SIDE_TOOL_X_SEARCH
# server_side_tools_used: SERVER_SIDE_TOOL_X_SEARCH
# server_side_tools_used: SERVER_SIDE_TOOL_WEB_SEARCH
# server_side_tools_used: SERVER_SIDE_TOOL_WEB_SEARCH
# server_side_tools_used: SERVER_SIDE_TOOL_WEB_SEARCH
#
# {'SERVER_SIDE_TOOL_X_SEARCH': 4, 'SERVER_SIDE_TOOL_WEB_SEARCH': 3}
#
#
# Server Side Tool Calls:
# [id: "call_72523050"
# type: TOOL_CALL_TYPE_X_SEARCH_TOOL
# function {
#   name: "x_user_search"
#   arguments: "{\"query\":\"xAI\",\"count\":5}"
# }
# , id: "call_13761307"
# type: TOOL_CALL_TYPE_X_SEARCH_TOOL
# function {
#   name: "x_keyword_search"
#   arguments: "{\"query\":\"from:xai\",\"limit\":20,\"mode\":\"Latest\"}"
# }
# , id: "call_03652169"
# type: TOOL_CALL_TYPE_X_SEARCH_TOOL
# function {
#   name: "x_keyword_search"
#   arguments: "{\"query\":\"from:xai OR from:elonmusk xai\",\"limit\":20,\"mode\":\"Latest\"}"
# }
# , id: "call_93304358"
# type: TOOL_CALL_TYPE_X_SEARCH_TOOL
# function {
#   name: "x_semantic_search"
#   arguments: "{\"query\":\"latest updates from xAI\",\"limit\":20,\"usernames\":[\"xai\"]}"
# }
# , id: "call_73478450"
# type: TOOL_CALL_TYPE_WEB_SEARCH_TOOL
# function {
#   name: "browse_page"
#   arguments: "{\"url\": \"https://x.ai/\"}"
# }
# , id: "call_70674405"
# type: TOOL_CALL_TYPE_WEB_SEARCH_TOOL
# function {
#   name: "browse_page"
#   arguments: "{\"url\": \"https://x.ai/blog\"}"
# }
# , id: "call_77200487"
# type: TOOL_CALL_TYPE_WEB_SEARCH_TOOL
# function {
#   name: "web_search"
#   arguments: "{\"query\":\"xAI latest updates news\",\"num_results\":15}"
# }
# ]
